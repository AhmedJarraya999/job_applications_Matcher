# %%
import pickle
from transformers import pipeline
translation = pipeline("translation", "Helsinki-NLP/opus-mt-fr-en")
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for PyTorch
# Failed to build PyTorch
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [6 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\azijo\AppData\Local\Temp\pip-install-e7h1v7qa\pytorch_bfffe41dd63047f0a29fb2eec8e3a0e1\setup.py", line 15, in <module>
#           raise Exception(message)
#       Exception: You tried to install "pytorch". The package named for PyTorch is "torch"
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for PyTorch
# ...

# %%
#SAVE THE MODEL IN A FILE (Translation_From_Frensh_words_to_English.pkl)
with open('Translation_From_Frensh_words_to_English.pkl', 'wb') as file:
    pickle.dump(translation, file)

# %%
with open('Translation_From_Frensh_words_to_English.pkl', 'rb') as file:
    loaded_model_pickle = pickle.load(file)
tr_text = loaded_model_pickle("Projet académique qui consiste à développer une application web,mobile et java qui permet à l'utilisateur de gérer les salles de sport. Technologies utilisées: PhpStorm, Codename One, Netbeans,Github, Trello, Photoshop, PhpMyAdmin.")
tr_text[0]["translation_text"]
# Out:
# 'Academic project which consists of developing a web, mobile and java application that allows the user to manage the gyms. Technologies used: PhpStorm, Codename One, Netbeans, Github, Trello, Photoshop, PhpMyAdmin.'
